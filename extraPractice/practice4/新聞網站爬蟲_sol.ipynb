# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import re


new_list = []
url = 'https://money.udn.com/money/index'

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

div_tag = soup.find_all('div', {'class':'story__list'})

#print(div_tag[0])

soup2 = BeautifulSoup(str(div_tag[0]), 'html.parser')
a_tags = soup2.find_all('a')

for i in a_tags:
    print('title: {}, link: {}'.format(i.text.replace(' ','').replace('\n',''), 'https://money.udn.com'+i['href']))
    new_list.append('https://money.udn.com'+i['href'])
# Out:
# title: 經部國營事業考績待政院核定年終上看4.4個月, link: https://money.udn.com/money/story/5612/6341478?from=edn_newest_index
# title: 拜登提軍事防衛台灣邱國正：自助才會人助, link: https://money.udn.com/money/story/7307/6341481?from=edn_newest_index
# title: 彩晶今日股東會通過配發1元現金股利, link: https://money.udn.com/money/story/5612/6341465?from=edn_newest_index
# title: 普亭簽署新令！簡化烏克蘭南部居民領俄羅斯護照程序, link: https://money.udn.com/money/story/5599/6341460?from=edn_newest_index

# %%
from time import sleep
import os
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

        
def save_news(url):
    
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}

    response = requests.get(url, headers=headers)
    sleep(1)
    soup = BeautifulSoup(response.text, 'html.parser')
    new_title = soup.find_all('h1',{'id':'story_art_title'})

    save_path = './news/'+new_title[0].text.replace(':','')
    
    article_body = soup.find_all('section',{'id':'article_body'})
    print('new title: {}'.format(new_title[0].text))

    ## create folder
    createFolder(save_path)
    soup2 = BeautifulSoup(str(article_body[0]), 'html.parser')


    ## save article contens in folder
    with open(save_path+'/contents.txt', 'w', encoding='utf-8') as f:  
        p_tags = soup2.find_all('p')
        print('new content: ')
        for i in p_tags:
            print(i.text)
            f.write(i.text)

    ## save image in article        
    img_tags = soup2.find_all('img')
    print('save image: ')
    for index, i in enumerate(img_tags):
        print(i['src'])
        urlretrieve(i['src'], save_path+'/'+str(index)+'.jpg')
    print('==========\n\n')
    

for new_url in new_list:
    print(new_url)
    save_news(new_url)
# Out:
# https://money.udn.com/money/story/5599/5947724?from=edn_newest_index
# new title: 蕭茲就任德國總理 習近平盼深化互信拓展合作
# new content:
# 新華社報導，中國國家主席習近平今天祝賀蕭茲（Olaf Scholz）就任德國總理，表示「願同你一道努力」，「推動中德關係邁上新台階」。
#
# 習近平也告訴蕭茲，他願意與蕭茲「鞏固並深化政治互信，拓展各領域交流合作」。
#
# 前總理梅克爾（Angela Merkel）在位16年後，蕭茲今天宣誓就任德國新總理，由中間偏左派領導的新聯盟政府領導這個歐洲最大經濟體。
#
# 蕭茲在聯邦議院（Bundestag，德國國會下議院）707票中贏得395票，他已宣示會廣泛「延續」梅克爾的政策，同時讓德國變得更環保且更公平。
#
# 根據新華社，習近平今天致電祝賀蕭茲時還說，中德兩國多年來堅持「求同存異」，並展現出「大國責任和擔當」。
#
# 現任美國總統拜登（Joe Biden）去年11月贏得總統大選後，北京沉默了數週才向他道賀，與習近平現在迅速恭賀蕭茲形成鮮明對比。
#
# 根據德國政府數據，中國是德國最大貿易夥伴，去年兩國間貨物貿易額達2132億歐元（約新台幣6兆6700億元）。
#
# 梅克爾曾被控對中國人權問題批評力道不足，像是新疆維吾爾族遭集體監禁等。批評者說，梅克爾受制於中國龐大的經濟利益。
#
# 蕭茲政府已保證會對俄羅斯與中國等專制國家採取更強硬立場。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5612/5947727?from=edn_newest_index
# new title: 金像電11月營收創歷史新高 Q4展望正向
# new content:
# 伺服器與NB用PCB供應商金像電（2368）（2368）今日公布11月營收達25.76億元，年增38.9%，創單月歷史新高。受惠於市場需求穩健成長，金像電表示，對第4季營運展望抱持正向。
#
#
#
# 就終端需求，金像電日前也提到，伺服器應用出貨順暢，相關訂單需求已至2022年，初步看來其餘網通應用也持平今年，同時商用NB用板明年首季也需求穩健。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/10511/5947720?from=edn_newest_index
# new title: 臉書祖克柏夫婦豪捐5億美元給母校哈佛 成立AI研究所
# new content:
# 社群媒體巨擘臉書CEO祖克柏夫婦（Mark Zuckerberg and Priscilla Chan）宣布將捐贈5億美元（約台幣139億元）在母校哈佛大學的工程及應用科學學院創立Kempner人工智慧研究所（AI institute），訂於2022年底開張，將延聘十位教師，新的運算設備，供學生研究如何結合數學、統計學和認知科學。祖克柏夫婦承諾捐贈5億美元給母校哈佛大學。美聯社
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/12/08/realtime/14727612.jpg&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
#
#
# https://money.udn.com/money/story/5599/5947711?from=edn_newest_index
# new title: 蕭茲就任德國總理 歐中俄領袖紛紛祝賀
# new content:
# 德國社會民主黨領袖蕭茲今天獲總統任命後返回國會，宣誓就任戰後第9位總理。對此，歐盟領袖表示期待與蕭茲聯手，共創更強大的歐盟；多國領導人也紛紛向蕭茲表達祝賀之意。
#
# 現年63歲、曾在前朝梅克爾政府擔任副總理與財政部長的蕭茲（Olaf Scholz），在聯邦議院（Bundestag）議長巴斯（Baerbel Bas）的主持下正式宣誓就職。聯邦議院稍早以395票比303票，同意蕭茲接替執政長達16年的前總理梅克爾，成為新任總理。
#
# 總理人選出爐後，歐盟執行委員會（EuropeanCommission）主席范德賴恩（Ursula von der Leyen）在推特以母語德文發文說，「恭喜蕭茲當選並獲任命為德國總理，祝您有個好的開始，也期待我們更加相信，能為歐洲強大而相互合作。」
#
# 法國總統馬克宏（Emmanuel Macron）推文表示，法德雙方「將為法國、德國以及全歐洲人民攜手譜寫下一個篇章」。馬克宏也不忘感謝梅克爾，稱她「永遠不忘記歷史的教訓，為我們做出這麼多貢獻，並與我們一同推動歐洲前進」。
#
# 俄羅斯總統蒲亭（Vladimir Putin）也發出賀電，祝賀蕭茲就職。克里姆林宮發言人培斯科夫（DmitryPeskov）說：「我們期待延續現狀，期待（蒲亭）總統與新總理（蕭茲）發展建設性關係，也期待德方像先前一樣，理解對話是化解最嚴重分歧的唯一方式。」
#
# 新華社等中國官媒報導，中國國家主席習近平也向蕭茲送上祝賀，並表示，「願鞏固並深化政治互信，拓展各領域交流合作」，同時推動中德關係邁上新台階。
# save image:
# ==========
